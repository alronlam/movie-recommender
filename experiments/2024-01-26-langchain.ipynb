# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain.storage import LocalFileStore
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import CacheBackedEmbeddings
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
import pandas as pd
import json
import os
from tqdm import tqdm
from sentence_transformers import CrossEncoder
import numpy as np
import time

from pathlib import Path

ROOT_DIR = Path("/home/alron/movie-recommender")
MOVIES_FILEPATH = ROOT_DIR/'data/movies_metadata.csv'


all_cols = pd.read_csv(MOVIES_FILEPATH).columns
search_cols = ["title", "overview", "genres"]
metadata_cols = [col for col in all_cols if col not in search_cols]

docs = CSVLoader(file_path=MOVIES_FILEPATH, metadata_columns=metadata_cols).load()


model_name = "BAAI/llm-embedder"
model_name_wo_org = Path(model_name).parts[-1]
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
bge_embedding_model = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)

store = LocalFileStore(ROOT_DIR/f"data/cache_{model_name_wo_org}/")

cached_embedder = CacheBackedEmbeddings.from_bytes_store(
    bge_embedding_model, store, namespace=model_name_wo_org
)


text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(docs)
# Out:
# /tmp/ipykernel_2470/2386381839.py:22: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_cols = pd.read_csv(MOVIES_FILEPATH).columns
# .gitattributes: 100%|██████████| 1.52k/1.52k [00:00<00:00, 9.79MB/s]
# 1_Pooling/config.json: 100%|██████████| 190/190 [00:00<00:00, 1.21MB/s]
# README.md: 100%|██████████| 28.8k/28.8k [00:00<00:00, 16.5MB/s]
# config.json: 100%|██████████| 731/731 [00:00<00:00, 4.24MB/s]
# config_sentence_transformers.json: 100%|██████████| 123/123 [00:00<00:00, 742kB/s]
# model.safetensors: 100%|██████████| 438M/438M [01:08<00:00, 6.41MB/s]
# pytorch_model.bin: 100%|██████████| 438M/438M [00:40<00:00, 10.7MB/s]
# sentence_bert_config.json: 100%|██████████| 53.0/53.0 [00:00<00:00, 312kB/s]
# special_tokens_map.json: 100%|██████████| 125/125 [00:00<00:00, 749kB/s]
# tokenizer.json: 100%|██████████| 712k/712k [00:00<00:00, 1.25MB/s]
# tokenizer_config.json: 100%|██████████| 396/396 [00:00<00:00, 2.48MB/s]
# vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 17.8MB/s]
# modules.json: 100%|██████████| 349/349 [00:00<00:00, 1.61MB/s]

# %%
# %%time
from tqdm import tqdm

FAISS_INDEX_PATH = ROOT_DIR/f"data/faiss_index_{model_name_wo_org}"

def load_or_generate_index(docs, cache_path=FAISS_INDEX_PATH):

    if os.path.exists(FAISS_INDEX_PATH):
        db = FAISS.load_local(cache_path, cached_embedder)
    else:
        db = None
        with tqdm(total=len(docs), desc="Ingesting documents") as pbar:
            for d in docs:
                if db:
                    db.add_documents([d])
                else:
                    db = FAISS.from_documents([d], cached_embedder)
                pbar.update(1)
        # db = FAISS.from_documents(documents[:100], cached_embedder)
        db.save_local(FAISS_INDEX_PATH)
    
    return db


db = load_or_generate_index(documents)
# Out:
# Ingesting documents: 100%|██████████| 45466/45466 [1:22:08<00:00,  9.22it/s]
# CPU times: user 10h 44min 42s, sys: 3.08 s, total: 10h 44min 45s
# Wall time: 1h 22min 10s

# %%
def doc_to_data_dict(doc):
    data = doc.page_content.split("\n")
    data_dict = {}
    for kv_tuple in data:
        try:
            key, value = kv_tuple.split(":", maxsplit=1)
            data_dict[key] = value
        except Exception:
            pass

    data_dict.update(doc.metadata)
    return data_dict

def rerank(cross_encoder, query, docs):
    
    # So we create the respective sentence combinations
    data_dicts = [doc_to_data_dict(doc) for doc in docs]
    sentence_combinations = [[query, ','.join(data_dict["genres"])+ " " +data_dict["title"] +" " + data_dict["overview"]] for data_dict in data_dicts]

    # Compute the similarity scores for these combinations
    similarity_scores = cross_encoder.predict(sentence_combinations)

    # Sort the scores in decreasing order
    sim_scores_argsort = list(reversed(np.argsort(similarity_scores)))

    # Print the scores
    # print("Query:", query)
    # for idx in sim_scores_argsort:
    #     print("{:.2f}\t{}".format(similarity_scores[idx], docs[idx]))

    reranked_docs = [docs[i] for i in sim_scores_argsort]
    scores = [similarity_scores[i] for i in sim_scores_argsort]

    return reranked_docs, scores
    

def print_doc_info(doc):
    data_dict = doc_to_data_dict(doc)

    print(data_dict['title'].strip())
    # print(doc.metadata["popularity"])
    print("---")
    print("Synopsis: ", data_dict['overview'].strip())
    genres = json.loads(data_dict['genres'].replace("'", '"'))
    print("Genres:", [x["name"] for x in genres])
    # print([x["name"] for x in ])
    print(f"Source: Row {doc.metadata['row']}, IMDB: https://imdb.com/title/{doc.metadata['imdb_id']}")
    print(doc.metadata)
    print()

# %%
cross_encoder = CrossEncoder('BAAI/bge-reranker-large')

# %%
QUERY = "ninja animated film for kids"
###########################################################

retriever = db.as_retriever(search_type="similarity_score_threshold", search_kwargs={"k": 20, "score_threshold": .5,})

start_retriever = time.time()
retriever_query = "Represent this sentence for searching relevant movie descriptions: " + QUERY
docs = retriever.get_relevant_documents(retriever_query)
end_retriever = time.time()
scores = [0 for i in range(len(docs))]


# Filter only to top 10 most popular
start_filter = time.time()
# docs = [doc for doc in docs if int(doc.metadata["vote_count"]) > 0]
# docs = sorted(docs, key=lambda doc: doc.metadata["vote_count"], reverse=True)
# docs = docs[:10]
end_filter = time.time()

start_reranker = time.time()
# docs, scores = rerank(cross_encoder, QUERY, docs)
# assert len(docs) > 0
# assert len(scores) > 0
end_reranker = time.time()

print(f"Retriever: {end_retriever-start_retriever:.2f}s")
print(f"Filter: {end_filter-start_filter:.2f}s")
print(f"Reranker: {end_reranker-start_reranker:.2f}s")


for doc, score in zip(docs, scores):
    print(f"[{score:.2f}]")
    print_doc_info(doc)
# Out:
# Retriever: 0.09s
# Filter: 0.00s
# Reranker: 0.00s
# [0.00]
# Pocket Ninjas
# ---
# Synopsis:  Somewhere in New Jersey, a group masked rollerblading children "save the universe" by training to fight the evil Cobra Khan through a series of action-packed montages.  Along the way they hypothesize some slapstick hijinks in a balloon factory, and save the day through a hypothetical Sonic Virtual Reality battle.  A real treat!
# Genres: ['Action', 'Family']
# Source: Row 30443, IMDB: https://imdb.com/title/tt0107838
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 30443, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '16530', 'imdb_id': 'tt0107838', 'original_language': 'en', 'original_title': 'Pocket Ninjas', 'popularity': '0.325189', 'poster_path': '/zu53XzaQivIi6Mzxt1ktHW5747W.jpg', 'production_companies': '[]', 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1997-03-25', 'revenue': '0', 'runtime': '80.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': 'The Fiercest Fighting Force Under Four Feet!', 'video': 'False', 'vote_average': '3.9', 'vote_count': '6'}
#
# [0.00]
# Ninja Academy
# ---
# Synopsis:  "Police Academy" styled film offers its laughs at the expense of students of the obvious school for ninjas.
# Genres: ['Comedy']
# Source: Row 30800, IMDB: https://imdb.com/title/tt0100265
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 30800, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '92496', 'imdb_id': 'tt0100265', 'original_language': 'en', 'original_title': 'Ninja Academy', 'popularity': '0.056566', 'poster_path': '/pFVUKEQbwS1gu1f9CZwHUqPMToE.jpg', 'production_companies': "[{'name': 'Omega Entertainment', 'id': 8101}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1989-08-17', 'revenue': '0', 'runtime': '120.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': "You don't have to be crazy to join, but if you are, it sure helps...", 'video': 'False', 'vote_average': '4.7', 'vote_count': '3'}
#
# [0.00]
# 3 Ninjas
# ---
# Synopsis:  Each year, three brothers Samuel, Jeffrey and Michael Douglas visits their Japanese grandfather, Mori Shintaro whom the boys affectionately refer to as Grandpa, for the summer. Mori is a highly skilled in the fields of Martial arts and Ninjutsu, and for years he has trained the boys in his techniques. After an organized crime ring proves to be too much for the FBI, it's time for the 3 brother NINJAS! To use their martial arts skills, they team up to battle the crime ring and outwit some very persistent kidnappers!
# Genres: ['Action', 'Adventure', 'Comedy', 'Family']
# Source: Row 4618, IMDB: https://imdb.com/title/tt0103596
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 4618, 'adult': 'False', 'belongs_to_collection': "{'id': 71458, 'name': '3 Ninjas Collection', 'poster_path': '/cApZ5GwwzMsA991J6uAOb52Js0s.jpg', 'backdrop_path': None}", 'budget': '0', 'homepage': '', 'id': '16314', 'imdb_id': 'tt0103596', 'original_language': 'en', 'original_title': '3 Ninjas', 'popularity': '11.035859', 'poster_path': '/lvfgYcK0dpgwCuRX4mTqc1Yg3yF.jpg', 'production_companies': "[{'name': 'Touchstone Pictures', 'id': 9195}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1992-08-07', 'revenue': '0', 'runtime': '84.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso_639_1': 'it', 'name': 'Italiano'}]", 'status': 'Released', 'tagline': 'Crosses Teenage Mutant Ninja Turtles and Home Alone!', 'video': 'False', 'vote_average': '5.5', 'vote_count': '102'}
#
# [0.00]
# Norwegian Ninja
# ---
# Synopsis:  Norwegian Ninja is the true story of how Commander Arne Treholt and his Ninja Force saved Norway during the Cold War. In 1983 the Ninja Force discovers that the sinister NATO force Stay Behind, who take charge in times of war and emergency, are planning a coup-d'état in peacetime. Treholt and the Ninjas see only one solution: a full can of whoop-ass.
# Genres: ['Drama', 'Action', 'Comedy', 'Thriller']
# Source: Row 25298, IMDB: https://imdb.com/title/tt1528769
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 25298, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '52009', 'imdb_id': 'tt1528769', 'original_language': 'en', 'original_title': 'Kommandør Treholt & ninjatroppen', 'popularity': '0.409606', 'poster_path': '/75S4DiP50raVOapldaI1NLVZ6C0.jpg', 'production_companies': '[]', 'production_countries': "[{'iso_3166_1': 'NO', 'name': 'Norway'}]", 'release_date': '2010-08-13', 'revenue': '0', 'runtime': '77.0', 'spoken_languages': "[{'iso_639_1': 'no', 'name': 'Norsk'}, {'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'ru', 'name': 'Pусский'}]", 'status': 'Released', 'tagline': '', 'video': 'False', 'vote_average': '3.8', 'vote_count': '10'}
#
# [0.00]
# 3 Ninjas: High Noon at Mega Mountain
# ---
# Synopsis:  Three young boys, Rocky, Colt and Tum Tum together with their neighbor girl, computer whiz Amanda are visiting Mega Mountain amusement park when it is invaded by an army of ninjas led by evil Medusa, who wants to take over the park and hold the owners for ransom. Kids and retired TV star Dave Dragon, who made his farewell appearance at the park at the time the ninjas appeared, have to break Medusa's vicious plans.
# Genres: ['Action', 'Comedy', 'Family']
# Source: Row 1654, IMDB: https://imdb.com/title/tt0118539
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 1654, 'adult': 'False', 'belongs_to_collection': "{'id': 71458, 'name': '3 Ninjas Collection', 'poster_path': '/cApZ5GwwzMsA991J6uAOb52Js0s.jpg', 'backdrop_path': None}", 'budget': '0', 'homepage': '', 'id': '32302', 'imdb_id': 'tt0118539', 'original_language': 'en', 'original_title': '3 Ninjas: High Noon at Mega Mountain', 'popularity': '3.014082', 'poster_path': '/qTavfpV1XWblnrfkASOxBnrdO0M.jpg', 'production_companies': "[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Leeds/Ben-Ami Productions', 'id': 27084}, {'name': 'Sheen Productions', 'id': 27085}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1998-04-10', 'revenue': '0', 'runtime': '93.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'de', 'name': 'Deutsch'}]", 'status': 'Released', 'tagline': 'Saving the day the ninja way!', 'video': 'False', 'vote_average': '3.9', 'vote_count': '38'}
#
# [0.00]
# Beverly Hills Ninja
# ---
# Synopsis:  Haru, an orphaned American who washes ashore in Japan and is mistaken for the great White Ninja of legend. Raised among the finest Ninjas, Haru grows strong and big - very big. With the grace of all Three Stooges rolled into one body, Haru is an embarrassment to his clan. But when a beautiful blonde pleads for his help, Haru is given one dangerous, disastrously funny chance to prove himself.
# Genres: ['Action', 'Comedy']
# Source: Row 1378, IMDB: https://imdb.com/title/tt0118708
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 1378, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '9622', 'imdb_id': 'tt0118708', 'original_language': 'en', 'original_title': 'Beverly Hills Ninja', 'popularity': '12.16305', 'poster_path': '/kHPiEtmMVLyFiYrvrCwRU9wVXBU.jpg', 'production_companies': "[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Motion Picture Corporation of America', 'id': 2090}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1997-01-17', 'revenue': '0', 'runtime': '88.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': "He put's the Mortal back in Kombat.", 'video': 'False', 'vote_average': '5.5', 'vote_count': '176'}
#
# [0.00]
# Ninja USA
# ---
# Synopsis:  Two cops are investigating a drug ring that may be led by an American man who saved them when they were kids. But when he kidnaps one's wife, they must fight through an army of ninjas to save her.
# Genres: ['Action']
# Source: Row 36504, IMDB: https://imdb.com/title/tt0400905
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 36504, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '197790', 'imdb_id': 'tt0400905', 'original_language': 'en', 'original_title': '猛龍煞星', 'popularity': '0.531679', 'poster_path': '/73Vis5BSfOjzimJSSUJPZj0u81F.jpg', 'production_companies': '[]', 'production_countries': '[]', 'release_date': '1985-01-01', 'revenue': '0', 'runtime': '95.0', 'spoken_languages': '[]', 'status': 'Released', 'tagline': "They're turning the American Dream into a Nightmare!", 'video': 'False', 'vote_average': '7.0', 'vote_count': '2'}
#
# [0.00]
# Ninja 2
# ---
# Synopsis:  [Period covered: 1582-1594]. As the film opens, the warlod Nobunaga Oda rides to Iga Ayanokuni shrine. He is asked if he thinks he has destroyed all the ninja who opposed him and answers that he suspects that there may be more. A servant brings water and tests it first. The paige dies and we hear gunshots as two ninja flee the scene. His suspicions confirmed, Nobunaga oversees the execution of captured ninja and decides that, in the future, he needs a much crueler method of execution. The daimyo Hideyoshi comes to visit.
# Genres: ['Action']
# Source: Row 22861, IMDB: https://imdb.com/title/tt0200310
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 22861, 'adult': 'False', 'belongs_to_collection': "{'id': 160677, 'name': 'Ninja, Band of Assassins Collection', 'poster_path': '/jZ9wA4Cr1UeCZSBz3Uz3XaLo7dr.jpg', 'backdrop_path': None}", 'budget': '0', 'homepage': '', 'id': '48707', 'imdb_id': 'tt0200310', 'original_language': 'ja', 'original_title': 'Zoku Shinobi no Mono', 'popularity': '0.294923', 'poster_path': '/7jw8B5ur4VqvoAdD0UNk3p8fEOe.jpg', 'production_companies': "[{'name': 'Daiei Studios', 'id': 881}]", 'production_countries': "[{'iso_3166_1': 'JP', 'name': 'Japan'}]", 'release_date': '1963-08-06', 'revenue': '0', 'runtime': '93.0', 'spoken_languages': "[{'iso_639_1': 'ja', 'name': '日本語'}]", 'status': 'Released', 'tagline': '', 'video': 'False', 'vote_average': '6.3', 'vote_count': '4'}
#
# [0.00]
# Ninja Assassin
# ---
# Synopsis:  Ninja Assassin follows Raizo (Rain), one of the deadliest assassins in the world. Taken from the streets as a child, he was transformed into a trained killer by the Ozunu Clan, a secret society whose very existence is considered a myth. But haunted by the merciless execution of his friend by the Clan, Raizo breaks free from them and vanishes. Now he waits, preparing to exact his revenge.
# Genres: ['Action', 'Crime', 'Thriller']
# Source: Row 14430, IMDB: https://imdb.com/title/tt1186367
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 14430, 'adult': 'False', 'belongs_to_collection': '', 'budget': '40000000', 'homepage': 'http://ninja-assassin-movie.warnerbros.com/', 'id': '22832', 'imdb_id': 'tt1186367', 'original_language': 'en', 'original_title': 'Ninja Assassin', 'popularity': '9.163897', 'poster_path': '/k0Nu7HuUdnjfeNPR6YSY0PDH2et.jpg', 'production_companies': "[{'name': 'Studio Babelsberg', 'id': 264}, {'name': 'Anarchos Productions', 'id': 450}, {'name': 'Legendary Pictures', 'id': 923}, {'name': 'Dark Castle Entertainment', 'id': 1786}, {'name': 'Silver Pictures', 'id': 1885}, {'name': 'Warner Bros.', 'id': 6194}, {'name': 'Medienboard Berlin-Brandenburg', 'id': 7307}, {'name': 'Deutsche Filmförderfonds (DFFF)', 'id': 11238}, {'name': 'Rocklock Films', 'id': 69582}]", 'production_countries': "[{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '2009-09-29', 'revenue': '60462347', 'runtime': '99.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': 'Fear not the weapon, but the hand that wields it.', 'video': 'False', 'vote_average': '6.2', 'vote_count': '384'}
#
# [0.00]
# Naruto Shippuden the Movie: Road to Ninja
# ---
# Synopsis:  Sixteen years ago, a mysterious masked ninja unleashes a powerful creature known as the Nine-Tailed Demon Fox on the Hidden Leaf Village Konoha, killing many people. In response, the Fourth Hokage Minato Namikaze and his wife Kushina Uzumaki, the Demon Fox's living prison or Jinchūriki, manage to seal the creature inside their newborn son Naruto Uzumaki. With the Tailed Beast sealed, things continued as normal. However, in the present day, peace ended when a group of ninja called the Akatsuki attack Konoha under the guidance of Tobi, the mysterious masked man behind Fox's rampage years ago who intends on executing his plan to rule the world by shrouding it in illusions.
# Genres: ['Fantasy', 'Animation', 'Action', 'Adventure']
# Source: Row 31166, IMDB: https://imdb.com/title/tt2290828
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 31166, 'adult': 'False', 'belongs_to_collection': "{'id': 23616, 'name': 'Naruto Collection', 'poster_path': '/cmKBGxVSAykHsnCL27wX4PIjNZI.jpg', 'backdrop_path': '/prLI2SNNkd9wcQkFh9iWXzQtR5D.jpg'}", 'budget': '0', 'homepage': 'http://www.naruto-movie.com/', 'id': '118406', 'imdb_id': 'tt2290828', 'original_language': 'ja', 'original_title': 'Road to Ninja: Naruto the Movie', 'popularity': '5.525454', 'poster_path': '/yJv9pLKJ6QzxgKMjuPmLl4JhcHu.jpg', 'production_companies': "[{'name': 'Dentsu Inc.', 'id': 1778}, {'name': 'Aniplex', 'id': 2883}, {'name': 'Shueisha', 'id': 2918}, {'name': 'TV Tokyo', 'id': 3034}, {'name': 'Toho', 'id': 5897}, {'name': 'Studio Pierrot Co. Ltd.', 'id': 6450}, {'name': 'Bandai', 'id': 6451}]", 'production_countries': "[{'iso_3166_1': 'JP', 'name': 'Japan'}]", 'release_date': '2012-07-28', 'revenue': '17322136', 'runtime': '109.0', 'spoken_languages': "[{'iso_639_1': 'ja', 'name': '日本語'}]", 'status': 'Released', 'tagline': '', 'video': 'False', 'vote_average': '7.4', 'vote_count': '81'}
#
# [0.00]
# Enter the Ninja
# ---
# Synopsis:  After completing his training of ninjutsu within Japan, an American Vietnam veteran by the name of Cole (Franco Nero) visits his war buddy Frank Landers (Alex Courtney) and his newly wed wife Mary Ann Landers (Susan George), who are the owners of a large piece of farming land in the Philippines. Cole soon finds that the Landers are being repeatedly harassed by a CEO named Charles Venarius.
# Genres: ['Crime', 'Action', 'Drama']
# Source: Row 5593, IMDB: https://imdb.com/title/tt0082332
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 5593, 'adult': 'False', 'belongs_to_collection': "{'id': 373538, 'name': 'Enter the Ninja Collection', 'poster_path': '/zmHiLeY4Mr0l5ZB9LIr42XNb5rN.jpg', 'backdrop_path': '/cj7F0fz5NGWhZKZmqxRnN7SpQc5.jpg'}", 'budget': '0', 'homepage': '', 'id': '17205', 'imdb_id': 'tt0082332', 'original_language': 'en', 'original_title': 'Enter the Ninja', 'popularity': '1.213727', 'poster_path': '/6FVrw8aME1wB8c1xXVQTrpkqabX.jpg', 'production_companies': "[{'name': 'City Film', 'id': 664}, {'name': 'Golan-Globus Productions', 'id': 13549}, {'name': 'The Cannon Group', 'id': 16414}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1981-07-17', 'revenue': '0', 'runtime': '100.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': 'Warriors of a lost martial art! Hired assassins ...human killing machines!', 'video': 'False', 'vote_average': '5.5', 'vote_count': '26'}
#
# [0.00]
# 3 Ninjas Kick Back
# ---
# Synopsis:  During a championship baseball match, the three brothers hear that their grandfather in Japan is in trouble, and head out to help him, conceding the match. When they arrive in Japan, they must use all their powers to defend him against his ancient enemy, who has returned to exact revenge.
# Genres: ['Adventure', 'Action', 'Comedy', 'Family']
# Source: Row 4619, IMDB: https://imdb.com/title/tt0109015
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 4619, 'adult': 'False', 'belongs_to_collection': "{'id': 71458, 'name': '3 Ninjas Collection', 'poster_path': '/cApZ5GwwzMsA991J6uAOb52Js0s.jpg', 'backdrop_path': None}", 'budget': '0', 'homepage': '', 'id': '18885', 'imdb_id': 'tt0109015', 'original_language': 'en', 'original_title': '3 Ninjas Kick Back', 'popularity': '3.775127', 'poster_path': '/paFMTv9IuZJaVkPZZvwtS5Ta5D9.jpg', 'production_companies': "[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Sheen Productions', 'id': 27085}, {'name': 'Ben-Ami/Leeds Productions', 'id': 37015}]", 'production_countries': "[{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1994-05-06', 'revenue': '0', 'runtime': '93.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]", 'status': 'Released', 'tagline': 'Colt, Rocky and Tum Tum are back for bigger kicks in an all new adventure', 'video': 'False', 'vote_average': '4.6', 'vote_count': '50'}
#
# [0.00]
# Naruto the Movie: Ninja Clash in the Land of Snow
# ---
# Synopsis:  Naruto is thrilled when he is sent on a mission to protect his favorite actress, Yukie Fujikaze, on the set of her new movie, The Adventures of Princess Gale. But when the crew ventures out to film in the icy, foreboding Land of Snow, Yukie mysteriously flees! Naruto and his squad set off to find her... unaware that three Snow Ninja lie in wait, with a sinister purpose that will force Yukie to face her hidden past!
# Genres: ['Comedy', 'Action', 'Animation', 'Adventure']
# Source: Row 35893, IMDB: https://imdb.com/title/tt0476680
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 35893, 'adult': 'False', 'belongs_to_collection': "{'id': 23616, 'name': 'Naruto Collection', 'poster_path': '/cmKBGxVSAykHsnCL27wX4PIjNZI.jpg', 'backdrop_path': '/prLI2SNNkd9wcQkFh9iWXzQtR5D.jpg'}", 'budget': '0', 'homepage': 'http://pierrot.jp/title/naruto/movie/', 'id': '16907', 'imdb_id': 'tt0476680', 'original_language': 'ja', 'original_title': '劇場版 NARUTO 大活劇! 雪姫忍法帖だってばよ!!', 'popularity': '4.616039', 'poster_path': '/imBsBkySpNJ4eXZxpRnbfSl2mwn.jpg', 'production_companies': "[{'name': 'Bandai Visual Company (JAPAN)', 'id': 570}, {'name': 'Toho Company', 'id': 882}, {'name': 'Dentsu Inc.', 'id': 1778}, {'name': 'Aniplex', 'id': 2883}, {'name': 'Shueisha', 'id': 2918}, {'name': 'TV Tokyo', 'id': 3034}, {'name': 'Studio Pierrot', 'id': 3234}]", 'production_countries': "[{'iso_3166_1': 'JP', 'name': 'Japan'}]", 'release_date': '2004-08-21', 'revenue': '0', 'runtime': '82.0', 'spoken_languages': "[{'iso_639_1': 'ja', 'name': '日本語'}]", 'status': 'Released', 'tagline': '', 'video': 'False', 'vote_average': '6.2', 'vote_count': '72'}
#
# [0.00]
# Dancing Ninja
# ---
# Synopsis:  An orphaned boy who dreams of being a ninja arrives in Hollywood and attempts to find his birth parents.
# Genres: ['Action', 'Comedy', 'Crime']
# Source: Row 36855, IMDB: https://imdb.com/title/tt1294141
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 36855, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '278778', 'imdb_id': 'tt1294141', 'original_language': 'en', 'original_title': 'Dancing Ninja', 'popularity': '0.205246', 'poster_path': '/cSmZsXhHi4BwroWmQ5qYQvcAPBH.jpg', 'production_companies': "[{'name': 'ATM Motionwide', 'id': 52103}, {'name': 'GV Entertainment', 'id': 52104}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}, {'iso_3166_1': 'KR', 'name': 'South Korea'}, {'iso_3166_1': 'CA', 'name': 'Canada'}]", 'release_date': '2013-10-08', 'revenue': '0', 'runtime': '97.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': "He's a Kung Fool Fighter!", 'video': 'False', 'vote_average': '4.7', 'vote_count': '3'}
#
# [0.00]
# Lethal Ninja
# ---
# Synopsis:  An American ninja's wife is held hostage by a sadistic Nazi chemist on an Asian island. He teams up with an African-American ninja to rescue her.
# Genres: ['Action', 'Thriller']
# Source: Row 26897, IMDB: https://imdb.com/title/tt0107392
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 26897, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '60139', 'imdb_id': 'tt0107392', 'original_language': 'fr', 'original_title': 'Lethal Ninja', 'popularity': '0.334247', 'poster_path': '/fcMbjmldQFlpoWIzLGloII9HbMY.jpg', 'production_companies': "[{'name': 'Nu Image Films', 'id': 925}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1993-04-19', 'revenue': '0', 'runtime': '97.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': 'Confronted by an evil force...this time the fight is personal...to save the woman he loves.', 'video': 'False', 'vote_average': '3.9', 'vote_count': '5'}
#
# [0.00]
# Ninja 1
# ---
# Synopsis:  [Period covered: 1575-1681] Fist film in the Shinobi series starring Raizo Ichikawa. Warlord Oda Nobunaga seeks to unite a fractured Japan, a young man trained in the arts of ninjitsu is manipulated by a ninja master into attempting to assassinate the warlord before he completes his task.
# Genres: ['Action', 'Foreign']
# Source: Row 22111, IMDB: https://imdb.com/title/tt0164882
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 22111, 'adult': 'False', 'belongs_to_collection': "{'id': 160677, 'name': 'Ninja, Band of Assassins Collection', 'poster_path': '/jZ9wA4Cr1UeCZSBz3Uz3XaLo7dr.jpg', 'backdrop_path': None}", 'budget': '0', 'homepage': '', 'id': '31297', 'imdb_id': 'tt0164882', 'original_language': 'ja', 'original_title': 'Shinobi no Mono', 'popularity': '0.924169', 'poster_path': '/fcH11zHrv3pqvx86UpVnDtggTaR.jpg', 'production_companies': "[{'name': 'Daiei Studios', 'id': 881}]", 'production_countries': "[{'iso_3166_1': 'JP', 'name': 'Japan'}]", 'release_date': '1962-12-01', 'revenue': '0', 'runtime': '104.0', 'spoken_languages': "[{'iso_639_1': 'ja', 'name': '日本語'}]", 'status': 'Released', 'tagline': 'The Film that made Ninjas legendary!', 'video': 'False', 'vote_average': '6.5', 'vote_count': '8'}
#
# [0.00]
# Ninja Scroll
# ---
# Synopsis:  Jubei is a masterless ninja who travels the land alone, hiring his services to those with gold... or a worthy cause. His fearsome abilities have served him well, but a hideous plot to overthrow the government threatens to end his wandering ways and possibly his life.
# Genres: ['Action', 'Animation', 'Fantasy']
# Source: Row 6708, IMDB: https://imdb.com/title/tt0107692
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 6708, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '14282', 'imdb_id': 'tt0107692', 'original_language': 'ja', 'original_title': '獣兵衛忍風帖', 'popularity': '7.634365', 'poster_path': '/s2uZIa9ZrdKxJnpyiS83YDxwk5.jpg', 'production_companies': "[{'name': 'Madhouse', 'id': 4288}]", 'production_countries': "[{'iso_3166_1': 'JP', 'name': 'Japan'}]", 'release_date': '1993-06-05', 'revenue': '0', 'runtime': '94.0', 'spoken_languages': "[{'iso_639_1': 'ja', 'name': '日本語'}]", 'status': 'Released', 'tagline': 'Feudal Japan - A Time of Danger, Intrigue and Deception...', 'video': 'False', 'vote_average': '7.4', 'vote_count': '126'}
#
# [0.00]
# 9 Deaths of the Ninja
# ---
# Synopsis:  A group of drug runners/freedom fighters has kidnapped a busload of tourists in the Philippines and is threatening to kill them all if one of their partners is not released from prison and the government doesn't halt its anti-drug policies. To stop the criminals, a trio of specialist soldiers are called in. Even with all their training, will they be able to stop the terrorists when they begin killing hostages and turning loose their squads of attack midgets?
# Genres: ['Action', 'Comedy']
# Source: Row 8873, IMDB: https://imdb.com/title/tt0089689
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 8873, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': 'http://www.crownintlpictures.com/lntitles.html', 'id': '51878', 'imdb_id': 'tt0089689', 'original_language': 'en', 'original_title': '9 Deaths of the Ninja', 'popularity': '0.956302', 'poster_path': '/yI5V6mz5ohdSk7e8yDY2V1JQTQg.jpg', 'production_companies': "[{'name': 'Crown International Pictures', 'id': 1009}]", 'production_countries': "[{'iso_3166_1': 'PH', 'name': 'Philippines'}]", 'release_date': '1985-04-15', 'revenue': '0', 'runtime': '94.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': 'The Ninja Master... is now The Ninja Avenger', 'video': 'False', 'vote_average': '6.1', 'vote_count': '9'}
#
# [0.00]
# 3 Ninjas Knuckle Up
# ---
# Synopsis:  Rocky, Colt and TumTum must battle an evil wealthy toxic waste dumper in order to save a local Indian tribe and their friend Joe. The 3 Ninjas must help find Joe's father and find a secret disk that contains evidence that could stop the toxic landfill that is destroying the Indian community. However the town is owned by the rich man and he controls the police and even the mayor. They must fight a motorcycle gang and renegade cowboys in this non-stop ninja adventure.
# Genres: ['Adventure', 'Action', 'Comedy', 'Family']
# Source: Row 4620, IMDB: https://imdb.com/title/tt0112255
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 4620, 'adult': 'False', 'belongs_to_collection': "{'id': 71458, 'name': '3 Ninjas Collection', 'poster_path': '/cApZ5GwwzMsA991J6uAOb52Js0s.jpg', 'backdrop_path': None}", 'budget': '0', 'homepage': '', 'id': '40508', 'imdb_id': 'tt0112255', 'original_language': 'en', 'original_title': '3 Ninjas Knuckle Up', 'popularity': '2.544118', 'poster_path': '/bd9if2VRAxBrXxkhT28hXMiusY1.jpg', 'production_companies': "[{'name': 'TriStar Pictures', 'id': 559}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1995-04-07', 'revenue': '0', 'runtime': '85.0', 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': 'Tum Tum, Colt and Rocky are back for all new non-stop Ninja action!', 'video': 'False', 'vote_average': '4.2', 'vote_count': '32'}
#
# [0.00]
# Five Element Ninjas
# ---
# Synopsis:  A young martial artist seeks revenge on the ninja who kills his martial arts brothers and teacher.
# Genres: ['Action']
# Source: Row 30662, IMDB: https://imdb.com/title/tt0084921
# {'source': PosixPath('/home/alron/movie-recommender/data/movies_metadata.csv'), 'row': 30662, 'adult': 'False', 'belongs_to_collection': '', 'budget': '0', 'homepage': '', 'id': '41378', 'imdb_id': 'tt0084921', 'original_language': 'zh', 'original_title': '五遁忍術', 'popularity': '2.453541', 'poster_path': '/pfzOJ7kDPgBnHKJekay9w2LsAQu.jpg', 'production_companies': "[{'name': 'Shaw Brothers', 'id': 5798}]", 'production_countries': '[]', 'release_date': '1982-04-21', 'revenue': '0', 'runtime': '107.0', 'spoken_languages': "[{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'iso_639_1': 'zh', 'name': '普通话'}]", 'status': 'Released', 'tagline': '', 'video': 'False', 'vote_average': '6.8', 'vote_count': '16'}
